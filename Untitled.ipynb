# %%
import pandas as pd

# %%
atos = pd.read_excel('Raw data.xlsx')

# %%
atos
# Out:
#      Call Record ID (SD)                          Title (SD)  Open Date  \
# 0            CALL4255792  Консультация по удаленному доступу 2021-07-05
# 1            CALL4255970     Консультация по созданию заявки 2021-07-05
# 2            CALL4255971            Консультация по планшету 2021-07-05
# 3            CALL4255990     Консультация по созданию заявки 2021-07-05
# 4            CALL4255995  Консультация по работе с планшетом 2021-07-05
# ...                  ...                                 ...        ...
# 1591         CALL4358852       Консультация по смене пароля  2021-07-31
# 1592         CALL4358941  Консультация по удаленному доступу 2021-07-31
# 1593         CALL4358949        Консультация по смене пароля 2021-07-31
# 1594         CALL4359038  Консультация по удаленному доступу 2021-07-31
# 1595         CALL4359505        Консультация по работе почты 2021-07-31
#
#        Call Type (SD) Full Name (SD Agent) Location Country (Caller)
# ...
